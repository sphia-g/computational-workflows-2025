# %% [markdown]
# # A short introduction to containerized software
#
# After spending time using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
# !docker info
# Out:
# Client:
#  Version:    28.4.0
#  Context:    desktop-linux
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.9.11
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.28.0-desktop.1
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.4.29
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.39.4-desktop.1
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.42
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.2.0
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-desktop
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.31
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  v0.21.0
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-mcp
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.18.3
#     Path:     /Users/sophiag/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 4
#   Running: 0
#   Paused: 0
#   Stopped: 4
#  Images: 12
#  Server Version: 28.4.0
#  Storage Driver: overlayfs
#   driver-type: io.containerd.snapshotter.v1
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  CDI spec directories:
#   /etc/cdi
#   /var/run/cdi
#  Discovered Devices:
#   cdi: docker.com/gpu=webgpu
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.5-0-g59923ef
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Docker Desktop
#  OSType: linux
#  Architecture: x86_64
#  CPUs: 8
#  Total Memory: 3.822GiB
#  Name: docker-desktop
#  ID: bc271926-1294-4ed7-ba3c-1af8b37d3018
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  HTTP Proxy: http.docker.internal:3128
#  HTTPS Proxy: http.docker.internal:3128
#  No Proxy: hubproxy.docker.internal
#  Labels:
#   com.docker.desktop.address=unix:///Users/sophiag/Library/Containers/com.docker.docker/Data/docker-cli.sock
#  Experimental: false
#  Insecure Registries:
#   hubproxy.docker.internal:5555
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false

# %% [markdown]
# ### What is a container?

# %% [markdown]
# A lightweight, portable, and self-sufficient package that contains everything needed to run a piece of software consistently across different environments. It bundles together the application code along with its dependencies, libraries, configuration files, and runtime environment.

# %% [markdown]
# ### Why do we use containers?

# %% [markdown]
# We use containers because they bring consistency, efficiency, speed, scalability, and portability.

# %% [markdown]
# ### What is a docker image?

# %% [markdown]
# A blueprint for a container. Snapshot that defines everything the application needs to run.

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Login to docker

# %%
# This you need to do on the command line directly

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Find the container ID

# %%
# !docker ps -l
# Out:
# CONTAINER ID   IMAGE         COMMAND    CREATED        STATUS                    PORTS     NAMES
# c7cb70a3b596   hello-world   "/hello"   47 hours ago   Exited (0) 47 hours ago             mystifying_bouman

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker rm $(docker ps -lq)
# Out:
# c7cb70a3b596

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                                             COMMAND                  CREATED      STATUS                    PORTS     NAMES
# b251b22b31bc   hello-world                                                       "/hello"                 2 days ago   Exited (0) 2 days ago               friendly_poincare
# 460a738477d8   quay.io/biocontainers/bioconductor-deseq2:1.34.0--r41hc247a5b_3   "/usr/local/env-exec…"   2 days ago   Exited (255) 2 days ago             nxf-trN73ETGqThwA3JB0Y7NgP4T

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. Download FastQC using curl: `curl -O https://www.bioinformatics.babraham.ac.uk/projects/fastqc/fastqc_v0.12.1.zip`
# 2. Unzip the downloaded file: `unzip fastqc_v0.12.1.zip`
# 3. Navigate to the FastQC directory: `cd FastQC/`
# 4. Make the FastQC script executable: `chmod +x fastqc`
# 7. Run FastQC on your FASTQ file: `cd ..`
# `./FastQC/fastqc ./notebooks/day_02/SRFetch_results/fastq/SRX19144486_SRR23195516_1.fastq.gz`
# 8. View the generated HTML report in a web browser

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker pull community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# Out:
# 0.12.1--af7a5314d5015c29: Pulling from library/fastqc
#
# c6865366: Pulling fs layer
# b700ef54: Pulling fs layer
# a01cff0b: Pulling fs layer
# 2b0c44d2: Pulling fs layer
# 97a3ef36: Pulling fs layer
# a16bbe82: Pulling fs layer
# 7ea432cc: Pulling fs layer
# d6c3110d: Pulling fs layer
# c00c10a5: Pulling fs layer
# b700ef54: Pulling fs layer
# acc3b8ff: Pulling fs layer
# 47592a0a: Pulling fs layer
# Digest: sha256:b7f6caf359264cf86da901b0aa5f66735a6506fcfbf103c66db6987253ad44c1[2KDownloading  17.83MB/29.75MBDownloading  19.92MB/29.75MBDownloading  20.97MB/29.75MBDownloading  20.97MB/29.75MBDownloading  24.12MB/29.75MBDownloading  11.53MB/368.2MBDownloading  16.78MB/368.2MBDownloading  16.78MB/368.2MBDownloading  18.87MB/368.2MBDownloading  96.47MB/368.2MBDownloading    107MB/368.2MBDownloading  114.3MB/368.2MBDownloading  135.3MB/368.2MBDownloading  146.8MB/368.2MBDownloading  162.5MB/368.2MBDownloading  165.7MB/368.2MBDownloading  203.4MB/368.2MBDownloading  335.5MB/368.2MBDownloading  343.9MB/368.2MBDownloading  358.6MB/368.2MB
# Status: Downloaded newer image for community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29

# %%
# run the container and save the results to a new "fastqc_results" directory

# Create output directory first
# !mkdir -p fastqc_results

# %%
# !pwd
# Out:
# /Users/sophiag/Documents/Dokumente/Studium/Master/FS4/ComputationalWorkflows/computational-workflows-2025/notebooks/day_03_part2

# %%
# run the container and save the results to a new "fastqc_results" directory/Users/sophiag/Documents/Dokumente/Studium/Master/FS4/ComputationalWorkflows/computational-workflows-2025/notebooks:/data
# !docker run --rm -v  \
  community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29 \
  fastqc /data/day_02/SRFetch_results/fastq/SRX19144486_SRR23195516_1.fastq.gz \
  -o /data/day_03_part2/fastqc_results
# Out:
# application/gzip
# Started analysis of SRX19144486_SRR23195516_1.fastq.gz
# Approx 5% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 10% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 15% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 20% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 25% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 30% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 35% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 40% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 45% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 50% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 55% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 60% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 65% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 70% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 75% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 80% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 85% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 90% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 95% complete for SRX19144486_SRR23195516_1.fastq.gz
# Analysis complete for SRX19144486_SRR23195516_1.fastq.gz

# %% [markdown]
# ### Now that you know how to use a docker container, which approach was easier and which approach will be easier in the future?

# %% [markdown]
# Although pulling the Biocontainer took a longer time it will be more robust and fast when using it in the future. Doing fastqc both via the command line and docker needed some trial and error.

# %% [markdown]
# ### What would you say, which approach is more reproducible?

# %% [markdown]
# I think using docker will be more reproducible. It doesnt need a lot of documentation and still will leverage the same versions and run in the same way when running it again at some later timepoint.

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?

# %% [markdown]
# Yes, the files look similar (manual inspection)

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# open the file "my_dockerfile" in a text editor

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %% [markdown]
# RUN line: This command updates the package list (apt-get update), installs cowsay and curl (apt-get install -y cowsay curl), and then cleans up package cache to reduce image size (apt-get clean && rm -rf /var/lib/apt/lists/*).
#
# ENV line: The PATH variable is set to include /usr/games because cowsay is installed in /usr/games/cowsay on Debian systems. By adding /usr/games to the PATH, we can run cowsay directly without specifying the full path /usr/games/cowsay.

# %%
# build the docker image
# !docker build -t my-cowsay-image -f my_dockerfile .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.1s
# [+] Building 0.4s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.4s
# [+] Building 0.7s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.8s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
# [+] Building 1.0s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
# [+] Building 1.0s (1/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.2s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.3s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.5s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.4s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.6s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.8s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.9s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.1s (3/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
# [+] Building 2.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
# [+] Building 2.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.2s
# [+] Building 2.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.3s
# [+] Building 2.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 1.05MB / 30.26MB  0.4s
# [+] Building 2.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 1.05MB / 30.26MB  0.6s
# [+] Building 2.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 2.10MB / 30.26MB  0.6s
# [+] Building 3.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 4.19MB / 30.26MB  0.7s
# [+] Building 3.1s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 6.29MB / 30.26MB  0.9s
# [+] Building 3.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 7.34MB / 30.26MB  1.0s
# [+] Building 3.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  1.2s
# [+] Building 3.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  1.4s
# [+] Building 3.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  1.4s
# [+] Building 3.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 11.53MB / 30.26MB  1.6s
# [+] Building 4.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 13.63MB / 30.26MB  1.8s
# [+] Building 4.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 14.68MB / 30.26MB  1.9s
# [+] Building 4.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 14.68MB / 30.26MB  2.1s
# [+] Building 4.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 16.78MB / 30.26MB  2.1s
# [+] Building 4.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 17.83MB / 30.26MB  2.2s
# [+] Building 4.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 17.83MB / 30.26MB  2.4s
# [+] Building 4.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 19.92MB / 30.26MB  2.4s
# [+] Building 4.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 20.97MB / 30.26MB  2.5s
# [+] Building 4.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 23.07MB / 30.26MB  2.7s
# [+] Building 5.1s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 25.17MB / 30.26MB  2.8s
# [+] Building 5.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 25.17MB / 30.26MB  3.0s
# [+] Building 5.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 26.21MB / 30.26MB  3.0s
# [+] Building 5.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 26.21MB / 30.26MB  3.1s
# [+] Building 5.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 28.31MB / 30.26MB  3.1s
# [+] Building 5.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
# [+] Building 5.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.1s
# [+] Building 5.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.3s
# [+] Building 6.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.4s
# [+] Building 6.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.6s
# [+] Building 6.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.7s
# [+] Building 6.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.9s
# [+] Building 6.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.0s
# [+] Building 6.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
# [+] Building 6.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.3s
# [+] Building 7.1s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.5s
# [+] Building 7.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.6s
# [+] Building 7.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
# [+] Building 7.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-get  0.1s
# [+] Building 7.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-get  0.3s
# [+] Building 7.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-get  0.4s
# [+] Building 8.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-get  0.6s
# [+] Building 8.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-get  0.6s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 8.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-get  0.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 8.3s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-get  1.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 8.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-get  1.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# ...
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     5.2s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               0.6s
# [+] Building 29.5s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     5.3s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               0.7s
# [+] Building 29.7s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     5.5s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               0.9s
# [+] Building 29.8s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     5.7s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               1.1s
# [+] Building 30.0s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     5.8s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               1.2s
# [+] Building 30.1s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     5.9s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               1.3s
# [+] Building 30.3s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     6.1s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               1.5s
# [+] Building 30.3s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     6.2s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               1.6s
# [+] Building 30.6s (7/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     6.2s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               1.6s
# [+] Building 30.6s (7/7) FINISHED                          docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 844B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  3.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.8s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay curl && apt-ge  16.8s
#  => exporting to image                                                     6.2s
#  => => exporting layers                                                    4.4s
#  => => exporting manifest sha256:f81cbd1621321d4be756d07a12129e1c6640d90e  0.1s
#  => => exporting config sha256:87d400ebdfc38d4c8ca6ea2172b16b1d4f788c00ec  0.0s
#  => => exporting attestation manifest sha256:6230b5d73b9fcdca18869b6516d8  0.0s
#  => => exporting manifest list sha256:f2bdfcc93251623958c82ab8ab8a49e4f94  0.0s
#  => => naming to docker.io/library/my-cowsay-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-cowsay-image:latest               1.6s
#
#  2 warnings found (use docker --debug to expand):
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 5)
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 6)

# %%
# make sure that the image has been built
# !docker images my-cowsay-image
# Out:
# REPOSITORY        TAG       IMAGE ID       CREATED              SIZE
# my-cowsay-image   latest    f2bdfcc93251   About a minute ago   197MB

# %%
# run the docker file 
# !docker run --rm my-cowsay-image cowsay "Yam yam yam"
# Out:
#  _____________
# < Yam yam yam >
#  -------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image

# %%
# build the image
# !docker build -t my-salmon-image -f salmon_docker .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.6s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.8s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.8s
# [+] Building 0.9s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
# [+] Building 1.1s (1/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.2s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.4s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.5s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.7s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.8s (3/3)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.0s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  0.2s
# [+] Building 2.1s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  0.3s
# [+] Building 2.3s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  0.5s
# [+] Building 2.4s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  0.6s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 2.5s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  0.7s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
# [+] Building 2.6s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  0.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.8s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  0.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.9s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  1.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.1s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  1.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.2s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  1.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.4s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  1.5s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.5s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  1.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.7s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  1.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.8s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  2.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.0s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  2.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.1s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  2.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.3s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  2.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.4s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  2.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.6s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  2.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.7s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  2.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.9s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  3.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.0s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  3.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.1s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  3.3s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
# [+] Building 5.2s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  3.4s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 5.4s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  3.5s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 5.5s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  3.7s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 5.7s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  3.8s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 5.8s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  4.0s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 6.0s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  4.1s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 6.1s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  4.3s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 6.3s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  4.4s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 6.3s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  4.4s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 4s (2154 kB/s)
#  => => # Reading package lists...
# [+] Building 6.4s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  4.6s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 4s (2154 kB/s)
#  => => # Reading package lists...
# [+] Building 6.6s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  4.7s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 4s (2154 kB/s)
#  => => # Reading package lists...
# [+] Building 6.7s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar     &  4.9s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 4s (2154 kB/s)
#  => => # Reading package lists...
# [+] Building 6.8s (5/8)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
# ...
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    10.0s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               1.5s
# [+] Building 31.6s (8/9)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    10.2s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               1.6s
# [+] Building 31.8s (8/9)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    10.3s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               1.8s
# [+] Building 31.9s (8/9)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    10.5s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               1.9s
# [+] Building 32.1s (8/9)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    10.6s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               2.1s
# [+] Building 32.2s (8/9)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    10.8s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               2.2s
# [+] Building 32.4s (8/9)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    10.9s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               2.4s
# [+] Building 32.4s (8/9)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    10.9s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               2.4s
# [+] Building 32.6s (9/9)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    11.0s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               2.4s
# [+] Building 32.6s (9/9) FINISHED                          docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 858B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/4] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/4] RUN apt-get update && apt-get install -y     curl     tar       11.1s
#  => [3/4] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  8.3s
#  => [4/4] RUN ldconfig                                                     0.3s
#  => exporting to image                                                    11.0s
#  => => exporting layers                                                    8.4s
#  => => exporting manifest sha256:7360ea0034eeeb8b9519488cd8ec4a02df429234  0.0s
#  => => exporting config sha256:5846e8302074d8966c3ff4dd9bf4e3b83390c76074  0.0s
#  => => exporting attestation manifest sha256:e05553f9893f2a673d34af36ca06  0.0s
#  => => exporting manifest list sha256:dfd8e1fb2e4af05c8d055b136eddbabd756  0.0s
#  => => naming to docker.io/library/my-salmon-image:latest                  0.0s
#  => => unpacking to docker.io/library/my-salmon-image:latest               2.4s
#
#  1 warning found (use docker --debug to expand):
#  - UndefinedVar: Usage of undefined variable '$LD_LIBRARY_PATH' (line 24)

# %%
# run the docker image to give out the version of salmon

# !docker run --rm my-salmon-image salmon --version
# Out:
# salmon 1.5.2

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# Find the salmon docker image online and run it on your computer.
#
# What is https://biocontainers.pro/ ?

# %% [markdown]
# No, most tools already have pre-built Docker images available.

# %%
# !docker pull community.wave.seqera.io/library/salmon:1.10.3--fcd0755dd8abb423
# Out:
# 1.10.3--fcd0755dd8abb423: Pulling from library/salmon
#
# 9ad3be4b: Pulling fs layer
# Digest: sha256:b4519ea6d76868516e8c545fd709bf900638cb4b9130206730e09038b2e9e274Downloading  31.46MB/67.61MB
# Status: Downloaded newer image for community.wave.seqera.io/library/salmon:1.10.3--fcd0755dd8abb423
# community.wave.seqera.io/library/salmon:1.10.3--fcd0755dd8abb423

# %%
# !docker run --rm community.wave.seqera.io/library/salmon:1.10.3--fcd0755dd8abb423 salmon --version
# Out:
# salmon 1.10.3

# %% [markdown]
# BioContainers is a community effort that provides Docker containers for bioinformatics tools

# %% [markdown]
# ## Are there other ways to create Docker (or Apptainer) images?
#
# What is https://seqera.io/containers/ ?

# %% [markdown]
# Yes, e.g. GUI tools. Also via GitHub
#
# Seqera Containers is a container provisioning service. You can search up the desireed docker and then pull it via the comand line easily.
