# %% [markdown]
# # Computational Workflows for biomedical data

# %% [markdown]
# Welcome to the course Computational Workflows for Biomedical Data. Over the next two weeks, you will learn how to leverage nf-core pipelines to analyze biomedical data and gain hands-on experience in creating your own pipelines, with a strong emphasis on Nextflow and nf-core.
#
# Course Structure:
#
# - Week 1: You will use a variety of nf-core pipelines to analyze a publicly available biomedical study.
# - Week 2: We will shift focus to learning the basics of Nextflow, enabling you to design and implement your own computational workflows.<br>
# - Final Project: The last couple of days, you will apply your knowledge to create a custom pipeline for analyzing biomedical data using Nextflow and the nf-core template.

# %% [markdown]
# ## Basics
#
# If you have not installed all required software, please do so now asap!
#
#
# If you already installed all software, please go on and start answering the questions in this notebook. If you have any questions, don't hesitate to approach us.

# %% [markdown]
# 1. What is nf-core?

# %% [markdown]
# nf-core hosts Nextflow pipelines for biosciences. It focuses on ensuring reproducibility and portability of pipelines across different hardware, operating systems, and software versions.

# %% [markdown]
# 2. How many pipelines are there currently in nf-core?

# %% [markdown]
# 139 pipelines

# %% [markdown]
# 3. Are there any non-bioinformatic pipelines in nf-core?

# %% [markdown]
# Yes, there are e.g. general data processing or infrastructure-related workflows.
# But also stuff related to financing, astronomy, ...

# %% [markdown]
# 4. Let's go back a couple of steps. What is a pipeline and what do we use it for?

# %% [markdown]
# A pipeline is a set of data processing elements connected in series, where the output of one element is the input of the next one. We would use them to save time, reduce errors, and make analyses reproducible and shareable.

# %% [markdown]
# 5. Why do you think nf-core adheres to strict guidelines?

# %% [markdown]
# To ensure reproducibility, maintainability and incrrease trust in the developed pipelines
# when everybody follows the guidelines it is easier to reproduce

# %% [markdown]
# 6. What are the main features of nf-core pipelines?

# %% [markdown]
# Sharable pipelines, comunity-driven, standardized and portable, modular

# %% [markdown]
# ## Let's start using the pipelines

# %% [markdown]
# 1. Find the nf-core pipeline used to measure differential abundance of genes

# %% [markdown]
# nf-core/differentialabundance

# %%
# run the pipeline in a cell 
# to run bash in jupyter notebooks, simply use ! before the command
# e.g.

# !pwd


# For the tasks in the first week, please use the command line to run your commands and simply paste the commands you used in the respective cells!

# %%
# run the pipeline in the test profile using docker containers
# make sure to specify the version you want to use (use the latest one)
# first do: gh auth login in terminal

# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker --outdir test_run
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [chaotic_mccarthy] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : chaotic_mccarthy
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/sophiag/Documents/Dokumente/Studium/Master/FS4/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/sophiag/Documents/Dokumente/Studium/Master/FS4/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/sophiag/.nextflow/assets/nf-core/differentialabundance
#   userName                    : sophiag
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : test_run
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (3)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [b7/9bfd69] NFC…Cherry_hND6_sample_number) | 0 of 2
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [b7/9bfd69] NFC…Cherry_hND6_sample_number) | 0 of 2
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (8)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 0 of 1
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 0 of 1
# [50/d906c4] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [50/d906c4] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [50/d906c4] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [50/d906c4] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [50/d906c4] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [37/d74d1b] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [5d/4e6cd1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [37/d74d1b] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [5d/4e6cd1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [a4/5a0939] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [37/d74d1b] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [5d/4e6cd1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [a4/5a0939] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [37/d74d1b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [5d/4e6cd1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [a4/5a0939] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [37/d74d1b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [cb/8b9429] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [5d/4e6cd1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [a4/5a0939] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [37/d74d1b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [cb/8b9429] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [47/33afc6] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [bc/a41898] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [a2/61806f] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [75/5e5855] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [1c/575880] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [5d/4e6cd1] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [a4/5a0939] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [1b/b8fb13] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [ac/ffcc87] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [37/d74d1b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
#
NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [97/6ef8b4] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [fc/8efa62] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [8e/44314d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [ed/fa636e] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [97/6ef8b4] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [fc/8efa62] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [8e/44314d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [ed/fa636e] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1 ✔
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [97/6ef8b4] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [fc/8efa62] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [8e/44314d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [ed/fa636e] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [97/6ef8b4] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [fc/8efa62] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [8e/44314d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [ed/fa636e] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [08/81afcd] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [97/6ef8b4] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [fc/8efa62] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [8e/44314d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [ed/fa636e] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [08/81afcd] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [97/6ef8b4] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [fc/8efa62] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [8e/44314d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [ed/fa636e] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [08/81afcd] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [97/6ef8b4] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [fc/8efa62] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [8e/44314d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [ed/fa636e] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [08/81afcd] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 14:24:55
# Duration    : 7m 39s
# CPU hours   : 0.1
# Succeeded   : 21

# %% [markdown]
# - run is executed similarly
# - took less time
# - hashes are different
# - reason: you dont have to re-download software because of the use of docker
#
# (in same output directory there are one more execution_report and execution_timeline plus pipeline_dag, params and execution_trace)

# %%
# now set -resume to the command. What did change?

# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker --outdir test_run -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [condescending_rutherford] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : condescending_rutherford
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/sophiag/Documents/Dokumente/Studium/Master/FS4/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/sophiag/Documents/Dokumente/Studium/Master/FS4/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/sophiag/.nextflow/assets/nf-core/differentialabundance
#   userName                    : sophiag
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : test_run
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [dd/060461] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [dd/060461] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [1e/188ddb] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [dd/060461] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [1e/188ddb] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [7c/5f2ef4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [dd/060461] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [69/cd5e20] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [1e/188ddb] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [7c/5f2ef4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [dd/060461] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [69/cd5e20] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [1e/188ddb] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [7c/5f2ef4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [08/81afcd] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [dd/060461] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [69/cd5e20] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [1e/188ddb] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [7c/5f2ef4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [08/81afcd] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [dd/060461] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [69/cd5e20] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [1e/188ddb] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [7c/5f2ef4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [08/81afcd] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [be/606524] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [96/c08147] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [32/0efca2] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [7f/e20b1e] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [6b/1dcae9] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [dd/060461] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [31/735ab2] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [3c/93d922] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [f6/02e5fa] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [50/1a0aaf] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [69/cd5e20] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [9d/854a07] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [1e/188ddb] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [7c/5f2ef4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [d9/9d4b38] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [08/81afcd] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔

# %% [markdown]
# Check out the current directory. Next to the outdir you specified, what else has changed?

# %% [markdown]
# - runs super fast
# - hashes are the same
# - reasons: reuses files instead of computing them from scratch; files are being cached instead of created from scratch

# %%
# delete the work directory and run the pipeline again using -resume. What did change?

# !nextflow run nf-core/differentialabundance -r 1.5.0 -profile test,docker --outdir test_run -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [deadly_shaw] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : deadly_shaw
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/sophiag/Documents/Dokumente/Studium/Master/FS4/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/sophiag/Documents/Dokumente/Studium/Master/FS4/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/sophiag/.nextflow/assets/nf-core/differentialabundance
#   userName                    : sophiag
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : test_run
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1 ✔
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [e9/2aca6e] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 1 of 2
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (8)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [11/1a123a] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [11/1a123a] NFC…, target:hND6, blocking:]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [11/1a123a] NFC…, target:hND6, blocking:]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 0 of 1
# [11/1a123a] NFC…, target:hND6, blocking:]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 0 of 1
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 0 of 1
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [3d/00bd28] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [3d/00bd28] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [a6/8c961c] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [a6/8c961c] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [a6/8c961c] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 0 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c1/c16aaa] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [df/1efb42] NFC…Cherry_hND6_sample_number) | 0 of 2
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c1/c16aaa] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [df/1efb42] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [df/1efb42] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [df/1efb42] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fa/7ce360] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [df/1efb42] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fa/7ce360] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [e5/81016d] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [df/1efb42] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fa/7ce360] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [e5/81016d] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [df/1efb42] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fa/7ce360] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [e5/81016d] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [b7/65184d] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [af/3f0c59] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [2c/258919] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3a/47d569] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [cb/812d46] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bd/7ab0bd] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [53/ecc108] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [7d/9b8e51] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [65/2626bd] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [01/3389e3] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [df/1efb42] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [f5/d0a6fb] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [96/b0302f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [43/889fca] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [fa/7ce360] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [e5/81016d] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 14:44:35
# Duration    : 6m 42s
# CPU hours   : 0.1
# Succeeded   : 21

# %% [markdown]
# What changed?
#
# - it ran from scratch again
# - took longer
# - new hashes
# - couldnt cache anything in the work directory because it was deleted previously

# %% [markdown]
# ## Lets look at the results

# %% [markdown]
# ### What is differential abundance analysis?

# %% [markdown]
# what it does: compare gene abundance e.g. in diseased vs. healthy tissue

# %% [markdown]
# Give the most important plots from the report:

# %%
# read in image
from matplotlib import pyplot as plt

img = plt.imread('../../images/density.png')

plt.imshow(img)

# %%
# read in image and display it
img = plt.imread('../../images/sample_dendrogram.png')

plt.imshow(img)
